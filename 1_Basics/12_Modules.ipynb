# %% [markdown]
# # User-Defined Modules

# %%
import job_analyzer

# %%
job_analyzer.calc_salary(10000,0.1)
# Out:
# 11000.0

# %%
from job_analyzer import *
calc_salary(10000,0.1)
calc_bonus(11000,10000)
# Out:
# 0.1

# %%
help(calc_salary)
# Out:
# Help on function calc_salary in module job_analyzer:
#
# calc_salary(base_sal, bonus_rate)
#     calculate the total salary based on the base salary and bonus rate

# %% [markdown]
# # Python Std Library

# %% [markdown]
# ## Statistics Module

# %%
salary_list = [10000, 11000, 12000, 13000, 14000]

# %%
from statistics import mean, median, mode

print(statistics.mean(salary_list))
print(statistics.median(salary_list))
print(statistics.mode(salary_list))
# Out:
# 12000
# 12000
# 10000
