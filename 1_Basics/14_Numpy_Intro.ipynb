# %% [markdown]
# # Intro

# %%
# create a list of 1M salaries ranging from 50K to 150K
import random

sal_list = [random.randint(50000,150000) for _ in range(1000000)]

# %%
import statistics

# %%
# %%timeit
statistics.mean(sal_list)
# Out:
# 267 ms ± 11.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(sal_list)
# Out:
# 75.3 ms ± 18.6 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Basics

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr.mean()
# Out:
# np.float64(3.0)

# %%
import numpy as np

# %%
job_titles = np.array(['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Engineer', 'AI Engineer'])

base_salaries = np.array([120000, 80000, 135000, 110000, np.nan])

bonus_rates = np.array([0.15, 0.10, 0.20, 0.12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([138000.,  88000., 162000., 123200.,     nan])

# %%
#  normal mean cant handle NaN values, use nanmean that time
#  np.mean(total_salaries)
np.nanmean(total_salaries)
# Out:
# np.float64(127800.0)
