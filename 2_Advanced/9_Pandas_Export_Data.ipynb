# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# load data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanup data
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# create a new column to use to concat on job posted month 

df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
# dictionary comprehension

months = df['job_posted_month'].unique()

dict_months = {month: df[df['job_posted_month'] == month] for month in months}

# %%
df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']])

df_q1
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 20         Data Scientist                                     Data Scientist
# 39          Data Engineer                                      Data Engineer
# 53          Data Engineer                                      Data Engineer
# 55         Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %% [markdown]
# - There are many methods to export data, can export to csv, clipboard, excel, sql , etc

# %%
# saving only a few cuz itll take a lot of space
df_q1.head(20).to_csv('q1_jobs.csv') # mention the file name to save to

# %%
# to read the csv file

pd.read_csv('q1_jobs.csv')
# Out:
#     Unnamed: 0        job_title_short  \
# 0            1           Data Analyst
# 1           20         Data Scientist
# 2           39          Data Engineer
# 3           53          Data Engineer
# 4           55         Data Scientist
# 5           56  Senior Data Scientist
# 6           58  Senior Data Scientist
# 7           60       Business Analyst
# 8           61          Data Engineer
# 9           69      Software Engineer
# 10          84         Data Scientist
# 11          91         Data Scientist
# 12         108          Data Engineer
# 13         131          Data Engineer
# 14         142           Data Analyst
# 15         155           Data Analyst
# 16         170           Data Analyst
# 17         171           Data Analyst
# 18         181           Data Analyst
# 19         187          Data Engineer
#
#                                             job_title  \
# 0                                        Data Analyst
# ...

# %% [markdown]
# - to remove the un-named column , do this

# %%
pd.read_csv('q1_jobs.csv', index_col=0)
# Out:
#            job_title_short                                          job_title  \
# 1             Data Analyst                                       Data Analyst
# 20          Data Scientist                                     Data Scientist
# 39           Data Engineer                                      Data Engineer
# 53           Data Engineer                                      Data Engineer
# 55          Data Scientist                                     Data Scientist
# 56   Senior Data Scientist                    Principal Statistical Scientist
# 58   Senior Data Scientist                              Senior Data Scientist
# 60        Business Analyst                       Business Intelligence Intern
# 61           Data Engineer                                      Data Engineer
# 69       Software Engineer                Software Engineer in Data Warehouse
# 84          Data Scientist                                       Data Science
# ...

# %% [markdown]
# - Exporting to excel file

# %%
df_q1.to_excel('q1_jobs.xlsx') # this will throw an error cuz a py excel module is needed , so need to install that 
# conda install openpyxl
# Out:
#   Cell In[19], line 2
#     ````
#     ^
# SyntaxError: invalid syntax

# %%
df_q1.head(50).to_excel('q1_jobs.xlsx')

# %% [markdown]
# to_sql()

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///jobs.db')

df_q1.head(100).to_sql('job_table', con=engine, if_exists = 'append', index = False)
# Out:
# 100

# %% [markdown]
# to_parquet() - reading and exporting data using this file is much more faster than csv

# %%
df_q1.head(1000).to_parquet('q1_jobs.parquet')

# %% [markdown]
# to_pickle() - same as parquet

# %%
df_q1.head(2000).to_pickle('q1_jobs.pkl')
