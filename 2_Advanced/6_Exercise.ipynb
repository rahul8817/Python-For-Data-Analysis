# %% [markdown]
# ## Analyzing DS Job Demand

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

# load data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# cleanup data
df['job_posted_data'] = pd.to_datetime(df['job_posted_date'])

# %%
df_IND = df[df['job_country'] == "India"].copy()

# %%
df_IND
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# 785718                      Senior Performance QA Analyst
# 785740                                 AWS System Analyst
#
#                       job_location  \
# 16        Pune, Maharashtra, India
# 19        Pune, Maharashtra, India
# 29        Pune, Maharashtra, India
# 38                           India
# 42      Chennai, Tamil Nadu, India
# ...                            ...
# 785712                       India
# 785715                       India
# 785716                       India
# 785718                       India
# 785740                       India
#
#                                                   job_via job_schedule_type  \
# 16                                           via LinkedIn         Full-time
# 19                                             via Indeed         Full-time
# 29                                             via Exusia         Full-time
# 38                                        via Trabajo.org         Full-time
# 42      via HR Software For Growing Businesses | Fresh...         Full-time
# ...                                                   ...               ...
# 785712                                melalui BeBee India   Pekerjaan tetap
# 785715  melalui Jobsleworld - Jobs In India - Job Vaca...   Pekerjaan tetap
# 785716                                melalui BeBee India   Pekerjaan tetap
# 785718                                melalui BeBee India   Pekerjaan tetap
# 785740                                     melalui Trigyn   Pekerjaan tetap
#
#         job_work_from_home search_location      job_posted_date  \
# 16                   False           India  2023-06-15 13:28:03
# 19                   False           India  2023-04-26 13:20:12
# 29                   False           India  2023-03-26 13:16:20
# 38                   False           India  2023-07-23 13:24:57
# 42                   False           India  2023-11-10 13:30:41
# ...                    ...             ...                  ...
# 785712               False           India  2023-03-13 06:16:31
# 785715               False           India  2023-03-13 06:16:28
# 785716               False           India  2023-03-13 06:16:31
# 785718               False           India  2023-03-13 06:16:28
# 785740               False           India  2023-03-13 06:16:31
#
#         job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 16                      False                 False       India        None
# 19                      False                 False       India        None
# 29                      False                 False       India        None
# 38                      False                 False       India        None
# 42                       True                 False       India        None
# ...                       ...                   ...         ...         ...
# 785712                  False                 False       India        None
# 785715                  False                 False       India        None
# 785716                  False                 False       India        None
# 785718                  False                 False       India        None
# 785740                  False                 False       India        None
#
#         salary_year_avg  salary_hour_avg                  company_name  \
# 16                  NaN              NaN         Hexaware Technologies
# 19                  NaN              NaN             Bitwise Solutions
# 29                  NaN              NaN                        Exusia
# 38                  NaN              NaN    Jones Lang LaSalle IP, Inc
# 42                  NaN              NaN                         CESIT
# ...                 ...              ...                           ...
# 785712              NaN              NaN  Varite India Private Limited
# 785715              NaN              NaN                          Amul
# 785716              NaN              NaN            CompuGroup Medical
# 785718              NaN              NaN               Diebold Nixdorf
# 785740              NaN              NaN                        Trigyn
#
#                                                job_skills  \
# 16      ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19      ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                                   None
# 38      ['sql', 'python', 'databricks', 'power bi', 'e...
# 42      ['python', 'sql', 'aws', 'pyspark', 'docker', ...
# ...                                                   ...
# 785712                                  ['excel', 'flow']
# 785715                                               None
# 785716                                      ['c#', 'sql']
# 785718                                               None
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills     job_posted_data
# 16      {'cloud': ['databricks', 'azure'], 'databases'... 2023-06-15 13:28:03
# 19      {'analyst_tools': ['tableau'], 'libraries': ['... 2023-04-26 13:20:12
# 29                                                   None 2023-03-26 13:16:20
# 38      {'analyst_tools': ['power bi', 'excel', 'word'... 2023-07-23 13:24:57
# 42      {'async': ['jira'], 'cloud': ['aws'], 'librari... 2023-11-10 13:30:41
# ...                                                   ...                 ...
# 785712    {'analyst_tools': ['excel'], 'other': ['flow']} 2023-03-13 06:16:31
# 785715                                               None 2023-03-13 06:16:28
# 785716                     {'programming': ['c#', 'sql']} 2023-03-13 06:16:31
# 785718                                               None 2023-03-13 06:16:28
# 785740              {'cloud': ['aws'], 'other': ['flow']} 2023-03-13 06:16:31
#
# [51088 rows x 18 columns]

# %%
df_IND['job_posted_date'].dtype
df_IND['job_posted_date'] = pd.to_datetime(df_IND['job_posted_date'], errors='coerce')

# %%
df_IND['job_posted_month'] = df_IND['job_posted_date'].dt.strftime('%B')
df_IND.head()
# Out:
#          job_title_short                                    job_title  \
# 16         Data Engineer                            Big Data Engineer
# 19        Data Scientist                               Data Scientist
# 29        Data Scientist                               Data Scientist
# 38          Data Analyst        Data Quality and Governance Analyst 1
# 42  Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                   job_location  \
# 16    Pune, Maharashtra, India
# 19    Pune, Maharashtra, India
# 29    Pune, Maharashtra, India
# 38                       India
# 42  Chennai, Tamil Nadu, India
#
#                                               job_via job_schedule_type  \
# 16                                       via LinkedIn         Full-time
# 19                                         via Indeed         Full-time
# 29                                         via Exusia         Full-time
# 38                                    via Trabajo.org         Full-time
# 42  via HR Software For Growing Businesses | Fresh...         Full-time
#
#     job_work_from_home search_location     job_posted_date  \
# 16               False           India 2023-06-15 13:28:03
# 19               False           India 2023-04-26 13:20:12
# 29               False           India 2023-03-26 13:16:20
# 38               False           India 2023-07-23 13:24:57
# 42               False           India 2023-11-10 13:30:41
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 16                  False                 False       India        None
# 19                  False                 False       India        None
# 29                  False                 False       India        None
# 38                  False                 False       India        None
# 42                   True                 False       India        None
#
#     salary_year_avg  salary_hour_avg                company_name  \
# 16              NaN              NaN       Hexaware Technologies
# 19              NaN              NaN           Bitwise Solutions
# 29              NaN              NaN                      Exusia
# 38              NaN              NaN  Jones Lang LaSalle IP, Inc
# 42              NaN              NaN                       CESIT
#
#                                            job_skills  \
# 16  ['powershell', 'python', 'sql', 'mysql', 'sql ...
# 19  ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 29                                               None
# 38  ['sql', 'python', 'databricks', 'power bi', 'e...
# 42  ['python', 'sql', 'aws', 'pyspark', 'docker', ...
#
#                                       job_type_skills     job_posted_data  \
# 16  {'cloud': ['databricks', 'azure'], 'databases'... 2023-06-15 13:28:03
# 19  {'analyst_tools': ['tableau'], 'libraries': ['... 2023-04-26 13:20:12
# 29                                               None 2023-03-26 13:16:20
# 38  {'analyst_tools': ['power bi', 'excel', 'word'... 2023-07-23 13:24:57
# 42  {'async': ['jira'], 'cloud': ['aws'], 'librari... 2023-11-10 13:30:41
#
#    job_posted_month
# 16             June
# 19            April
# 29            March
# 38             July
# 42         November

# %%
df_IND_table = df_IND.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# job_titles = ['Data Analyst', 'Data Engineer', 'Data Scientist']
df_IND_table
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# April                          170              32           418
# August                         189              25           618
# December                       186              27           648
# February                       143              35           433
# January                        175              31           628
# July                           142              25           457
# June                           146              26           367
# March                          116              37           422
# May                            103              14           278
# November                       192              29           722
# October                        170              36           500
# September                      155              34           630
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# April                      1566             946                         54
# August                     1407            1157                         47
# December                   1464            1206                         94
# February                   1631             932                         42
# January                    2132            1444                         70
# July                       1528            1123                         54
# June                       1632            1129                         41
# March                      1591            1005                         34
# May                        1384             837                         31
# November                   1743            1614                         52
# October                    1476             902                         85
# September                  1508             984                         67
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# April                              86                   375
# August                            126                   343
# December                           77                   343
# February                           94                   313
# January                           127                   448
# July                               75                   359
# June                               66                   427
# March                              96                   351
# May                                59                   329
# November                          125                   423
# October                            67                   318
# September                          85                   324
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# April                               194                169
# August                              235                148
# December                            200                133
# February                            165                157
# January                             269                192
# July                                204                155
# June                                238                125
# March                               194                180
# May                                 134                 98
# November                            278                139
# October                             180                167
# September                           195                132

# %%
# DONT RUN RESET ONCE ALREADY RUN, WIL CAUSE ERROR
# df_IND_table.reset_index(inplace=True)
df_IND_table['month_no'] = pd.to_datetime(df_IND_table['job_posted_month'], format='%B').dt.month

df_IND_table['month_no']
# Out:
# 4      1
# 3      2
# 7      3
# 0      4
# 8      5
# 6      6
# 5      7
# 1      8
# 11     9
# 10    10
# 9     11
# 2     12
# Name: month_no, dtype: int32

# %%
df_IND_table.sort_values('month_no', inplace=True)
df_IND_table.set_index('job_posted_month', inplace=True)

# month_no no more needed so drop it

df_IND_table.drop(columns='month_no', inplace=True)

# %%
# df_IND_table.drop(columns='index',inplace=True)
df_IND_table
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# January                    2132            1444                         70
# February                   1631             932                         42
# March                      1591            1005                         34
# April                      1566             946                         54
# May                        1384             837                         31
# June                       1632            1129                         41
# July                       1528            1123                         54
# August                     1407            1157                         47
# September                  1508             984                         67
# October                    1476             902                         85
# November                   1743            1614                         52
# December                   1464            1206                         94
#
# job_title_short   Senior Data Analyst  Senior Data Engineer  \
# job_posted_month
# January                           127                   448
# February                           94                   313
# March                              96                   351
# April                              86                   375
# May                                59                   329
# June                               66                   427
# July                               75                   359
# August                            126                   343
# September                          85                   324
# October                            67                   318
# November                          125                   423
# December                           77                   343
#
# job_title_short   Senior Data Scientist  Software Engineer
# job_posted_month
# January                             269                192
# February                            165                157
# March                               194                180
# April                               194                169
# May                                 134                 98
# June                                238                125
# July                                204                155
# August                              235                148
# September                           195                132
# October                             180                167
# November                            278                139
# December                            200                133

# %%
df_IND_table.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# cleaning up the plot

# %%
# finding out the top 3 job titles

top_3 = df_IND['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_IND_table[top_3]
# Out:
# job_title_short   Data Engineer  Data Scientist  Data Analyst
# job_posted_month
# January                    2132            1444           628
# February                   1631             932           433
# March                      1591            1005           422
# April                      1566             946           418
# May                        1384             837           278
# June                       1632            1129           367
# July                       1528            1123           457
# August                     1407            1157           618
# September                  1508             984           630
# October                    1476             902           500
# November                   1743            1614           722
# December                   1464            1206           648

# %%
df_IND_table[top_3].plot(kind='line')
plt.title("Monthly Job Postings for Top Jobs in India ")
plt.xlabel("Month")
plt.ylabel("Job Counts")
plt.legend()
plt.show()
