# %%
# Example

data = {
    'job_skills': [
        'Python',
        'SQL',
        'Excel',
        'Power BI',
        'Tableau',
        'AWS',
        'Machine Learning',
        'Statistics',
        'Data Visualization',
        'Pandas'
    ],
    'skill_count': [
        120,
        95,
        140,
        60,
        55,
        40,
        50,
        70,
        65,
        110
    ],
    'skill_pay': [
        12.5,   # Python
        11.0,   # SQL
        8.5,    # Excel
        10.0,   # Power BI
        10.2,   # Tableau
        14.0,   # AWS
        16.5,   # Machine Learning
        13.0,   # Statistics
        9.5,    # Data Visualization
        12.0    # Pandas
    ]
}
